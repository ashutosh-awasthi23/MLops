# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
## set the tracking uri
mlflow.set_tracking_uri(uri= "https://127.0.0.1:5000")

# %%
X,y = datasets.load_iris(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.20)

params = {
    "max_iter"  : 1000,
    "multi_class" : "auto",
    "random_state" : 8888,
    "penalty" : "l2"
}

lr = LogisticRegression(**params)

lr.fit(X_train,y_train)
# Out:
# e:\MLops\mlo\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
## Prediction on the test set
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 0, 2, 0, 0, 1, 1, 1, 2, 0, 0, 1, 1, 2, 0, 0, 1, 2, 0,
#        2, 2, 2, 2, 1, 1, 2, 1])

# %%
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9333333333333333

# %%
#### MLFLOW tracking
mlflow.set_tracking_uri(uri = "http://127.0.0.1:5000")

## create ml flow experiment
mlflow.set_experiment("MLFLOW Quickstart2")
## Start an MLolflFLOW_run
with mlflow.start_run():
    ## log the hyperparameters
    mlflow.log_params(params)

    ## log the accuracy matrics
    mlflow.log_metric("accuracy",accuracy)

    # Set atag that we can use to remind ourselves what this run was for
    mlflow.set_tag("Training Info","Basic LR model for iris data")

    ## Infer the model signature
    signature = infer_signature(X_train,lr.predict(X_train))


    ## Log the model
    model_info  = mlflow.sklearn.log_model(
        sk_model = lr,
        name = "iris_model",
        signature = signature,
        input_example = X_train, 
        registered_model_name= " tracking-quickstart2"

    )
# Out:
# Registered model ' tracking-quickstart2' already exists. Creating a new version of this model...
# 2025/11/04 18:17:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name:  tracking-quickstart2, version 4
# 🏃 View run gifted-skink-465 at: http://127.0.0.1:5000/#/experiments/741668014856225653/runs/52b1d1c1f02d4c20a96f0b3b3e85d6e6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/741668014856225653
# Created version '4' of model ' tracking-quickstart2'.

# %%
model_info.model_uri
# Out:
# 'models:/m-6da0e946e3d24467b43cf8572b942ed6'

# %%
from mlflow.models import validate_serving_input
model_uri = 'runs:741668014856225653/8c9e9a9914234ade9223f1be7d4fbe61/MLmodel'
serving_payload = """{
"inputs": [
    [
      6.4,
      3.2,
      4.5,
      1.5
    ],
    [
      5.9,
      3,
      5.1,
      1.8
    ],
    [
      6.5,
      2.8,
      4.6,
      1.5
    ],
    [
      4.6,
      3.1,
      1.5,
      0.2
    ],
    [
      6.7,
      2.5,
      5.8,
      1.8
    ],
    [
      6.7,
      3.3,
      5.7,
      2.1
    ],
    [
      6.3,
      2.3,
      4.4,
      1.3
    ],
    [
      6.3,
      2.5,
      5,
      1.9
    ],
    [
      5,
      3.5,
      1.3,
      0.3
    ],
    [
      6.1,
      2.8,
      4.7,
      1.2
    ],
    [
      7.9,
      3.8,
      6.4,
      2
    ],
    [
      4.4,
      3,
      1.3,
      0.2
    ],
    [
      7.7,
      2.6,
      6.9,
      2.3
    ],
    [
      6.5,
      3,
      5.5,
      1.8
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      5.8,
      4,
      1.2,
      0.2
    ],
    [
      5.6,
      2.9,
      3.6,
      1.3
    ],
    [
      5.5,
      4.2,
      1.4,
      0.2
    ],
    [
      4.9,
      3.1,
      1.5,
      0.2
    ],
    [
      4.6,
      3.6,
      1,
      0.2
    ],
    [
      6.7,
      3.1,
      4.7,
      1.5
    ],
    [
      6.1,
      3,
      4.6,
      1.4
    ],
    [
      6,
      2.2,
      4,
      1
    ],
    [
      5.2,
      3.5,
      1.5,
      0.2
    ],
    [
      5.4,
      3.7,
      1.5,
      0.2
    ],
    [
      5,
      3.4,
      1.5,
      0.2
    ],
    [
      7.1,
      3,
      5.9,
      2.1
    ],
    [
      6.3,
      2.5,
      4.9,
      1.5
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.7,
      2.5,
      5,
      2
    ],
    [
      4.9,
      2.5,
      4.5,
      1.7
    ],
    [
      5.9,
      3,
      4.2,
      1.5
    ],
    [
      5.1,
      3.8,
      1.9,
      0.4
    ],
    [
      5.5,
      2.6,
      4.4,
      1.2
    ],
    [
      6.4,
      3.1,
      5.5,
      1.8
    ],
    [
      5.1,
      3.3,
      1.7,
      0.5
    ],
    [
      5.7,
      3.8,
      1.7,
      0.3
    ],
    [
      6.1,
      2.8,
      4,
      1.3
    ],
    [
      5.8,
      2.8,
      5.1,
      2.4
    ],
    [
      4.5,
      2.3,
      1.3,
      0.3
    ],
    [
      6.2,
      2.9,
      4.3,
      1.3
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      6.5,
      3,
      5.2,
      2
    ],
    [
      6.8,
      2.8,
      4.8,
      1.4
    ],
    [
      6,
      3.4,
      4.5,
      1.6
    ],
    [
      5.4,
      3.4,
      1.7,
      0.2
    ],
    [
      7.7,
      2.8,
      6.7,
      2
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      4.9,
      3,
      1.4,
      0.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.2
    ],
    [
      6.1,
      2.6,
      5.6,
      1.4
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      6.9,
      3.1,
      5.1,
      2.3
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      5.1,
      3.4,
      1.5,
      0.2
    ],
    [
      5,
      3.6,
      1.4,
      0.2
    ],
    [
      5.5,
      2.3,
      4,
      1.3
    ],
    [
      5.6,
      2.7,
      4.2,
      1.3
    ],
    [
      5.7,
      2.6,
      3.5,
      1
    ],
    [
      5,
      3,
      1.6,
      0.2
    ],
    [
      6.5,
      3.2,
      5.1,
      2
    ],
    [
      7.2,
      3,
      5.8,
      1.6
    ],
    [
      4.4,
      2.9,
      1.4,
      0.2
    ],
    [
      4.8,
      3,
      1.4,
      0.3
    ],
    [
      6.2,
      2.2,
      4.5,
      1.5
    ],
    [
      5.5,
      2.4,
      3.7,
      1
    ],
    [
      5.6,
      2.8,
      4.9,
      2
    ],
    [
      4.6,
      3.2,
      1.4,
      0.2
    ],
    [
      7.3,
      2.9,
      6.3,
      1.8
    ],
    [
      5.9,
      3.2,
      4.8,
      1.8
    ],
    [
      5.5,
      2.4,
      3.8,
      1.1
    ],
    [
      6.3,
      2.7,
      4.9,
      1.8
    ],
    [
      4.3,
      3,
      1.1,
      0.1
    ],
    [
      5.2,
      3.4,
      1.4,
      0.2
    ],
    [
      7.4,
      2.8,
      6.1,
      1.9
    ],
    [
      5.7,
      3,
      4.2,
      1.2
    ],
    [
      6.3,
      3.3,
      6,
      2.5
    ],
    [
      6,
      2.9,
      4.5,
      1.5
    ],
    [
      5.1,
      3.5,
      1.4,
      0.3
    ],
    [
      7.2,
      3.2,
      6,
      1.8
    ],
    [
      6.7,
      3.1,
      4.4,
      1.4
    ],
    [
      5.1,
      2.5,
      3,
      1.1
    ],
    [
      7.7,
      3.8,
      6.7,
      2.2
    ],
    [
      5.8,
      2.6,
      4,
      1.2
    ],
    [
      6.8,
      3.2,
      5.9,
      2.3
    ],
    [
      5,
      3.2,
      1.2,
      0.2
    ],
    [
      4.9,
      3.1,
      1.5,
      0.1
    ],
    [
      6.7,
      3,
      5,
      1.7
    ],
    [
      5.2,
      4.1,
      1.5,
      0.1
    ],
    [
      6.9,
      3.1,
      4.9,
      1.5
    ],
    [
      6.4,
      3.2,
      5.3,
      2.3
    ],
    [
      4.9,
      2.4,
      3.3,
      1
    ],
    [
      5.1,
      3.8,
      1.5,
      0.3
    ],
    [
      7,
      3.2,
      4.7,
      1.4
    ],
    [
      5,
      3.5,
      1.6,
      0.6
    ],
    [
      6.9,
      3.2,
      5.7,
      2.3
    ],
    [
      4.8,
      3.1,
      1.6,
      0.2
    ],
    [
      7.6,
      3,
      6.6,
      2.1
    ],
    [
      4.8,
      3,
      1.4,
      0.1
    ],
    [
      6.1,
      2.9,
      4.7,
      1.4
    ],
    [
      6.6,
      2.9,
      4.6,
      1.3
    ],
    [
      5,
      3.4,
      1.6,
      0.4
    ],
    [
      6.7,
      3,
      5.2,
      2.3
    ],
    [
      4.7,
      3.2,
      1.3,
      0.2
    ],
    [
      6.1,
      3,
      4.9,
      1.8
    ],
    [
      6,
      3,
      4.8,
      1.8
    ],
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      5.5,
      3.5,
      1.3,
      0.2
    ],
    [
      6.7,
      3.1,
      5.6,
      2.4
    ],
    [
      7.2,
      3.6,
      6.1,
      2.5
    ],
    [
      5.6,
      3,
      4.1,
      1.3
    ],
    [
      6.8,
      3,
      5.5,
      2.1
    ],
    [
      6.5,
      3,
      5.8,
      2.2
    ],
    [
      5,
      2,
      3.5,
      1
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ],
    [
      5.4,
      3.9,
      1.7,
      0.4
    ],
    [
      5.7,
      4.4,
      1.5,
      0.4
    ],
    [
      6.3,
      3.3,
      4.7,
      1.6
    ],
    [
      5.4,
      3.9,
      1.3,
      0.4
    ],
    [
      5,
      2.3,
      3.3,
      1
    ]
  ]
}"""
validate_serving_input(model_uri,serving_payload)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[28], line 727
#       2 model_uri = 'runs:741668014856225653/8c9e9a9914234ade9223f1be7d4fbe61/MLmodel'
#       3 serving_payload = """{
#       4 "inputs": [
#       5     [
#    (...)    725   ]
#     726 }"""
# --> 727 validate_serving_input(model_uri,serving_payload)
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\models\utils.py:2007, in validate_serving_input(model_uri, serving_input)
#    2004 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    2006 try:
# -> 2007     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    2008     parsed_input = _parse_json_data(
#    2009         serving_input,
#    2010         pyfunc_model.metadata,
#    2011         pyfunc_model.metadata.get_input_schema(),
#    2012     )
#    2013     with _simulate_serving_environment():
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\tracing\provider.py:567, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     565 try:
#     566     is_func_called = True
# --> 567     result = f(*args, **kwargs)
#     568 finally:
#     569     enable()
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\pyfunc\__init__.py:1132, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1128         entity_list.append(Entity(job=job_entity))
#    1130     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1132 local_path = _download_artifact_from_uri(
#    1133     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1134 )
#    1136 if not suppress_warnings:
#    1137     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\tracking\artifact_utils.py:117, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri, registry_uri)
#     107 """
#     108 Args:
#     109     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)    114     registry_uri: The registry URI to be used when downloading artifacts.
#     115 """
#     116 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 117 repo = get_artifact_repository(
#     118     artifact_uri=root_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#     119 )
#     121 try:
#     122     if isinstance(repo, ModelsArtifactRepository):
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:147, in get_artifact_repository(artifact_uri, tracking_uri, registry_uri)
#     128 def get_artifact_repository(
#     129     artifact_uri: str, tracking_uri: str | None = None, registry_uri: str | None = None
#     130 ) -> ArtifactRepository:
#     131     """
#     132     Get an artifact repository from the registry based on the scheme of artifact_uri
#     133
#    (...)    145         requirements.
#     146     """
# --> 147     return _artifact_repository_registry.get_artifact_repository(
#     148         artifact_uri, tracking_uri, registry_uri
#     149     )
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:83, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri, tracking_uri, registry_uri)
#      78 if repository is None:
#      79     raise MlflowException(
#      80         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      81         f"Currently registered schemes are: {list(self._registry.keys())}"
#      82     )
# ---> 83 return repository(artifact_uri, tracking_uri=tracking_uri, registry_uri=registry_uri)
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:38, in RunsArtifactRepository.__init__(self, artifact_uri, tracking_uri, registry_uri)
#      35 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      37 super().__init__(artifact_uri, tracking_uri, registry_uri)
# ---> 38 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri, tracking_uri)
#      39 self.repo = get_artifact_repository(
#      40     uri, tracking_uri=self.tracking_uri, registry_uri=self.registry_uri
#      41 )
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:51, in RunsArtifactRepository.get_underlying_uri(runs_uri, tracking_uri)
#      47 @staticmethod
#      48 def get_underlying_uri(runs_uri: str, tracking_uri: str | None = None) -> str:
#      49     from mlflow.tracking.artifact_utils import get_artifact_uri
# ---> 51     (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      52     databricks_profile_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
#      53     uri = get_artifact_uri(
#      54         run_id=run_id,
#      55         artifact_path=artifact_path,
#      56         tracking_uri=databricks_profile_uri or tracking_uri,
#      57     )
#
# File e:\MLops\mlo\Lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:74, in RunsArtifactRepository.parse_runs_uri(run_uri)
#      72 path = parsed.path
#      73 if not path.startswith("/") or len(path) <= 1:
# ---> 74     raise MlflowException(
#      75         f"Not a proper runs:/ URI: {run_uri}. "
#      76         + "Runs URIs must be of the form 'runs:/<run_id>/run-relative/path/to/artifact'"
#      77     )
#      78 path = path[1:]
#      80 path_parts = path.split("/")
#
# MlflowException: Not a proper runs:/ URI: runs:741668014856225653/8c9e9a9914234ade9223f1be7d4fbe61. Runs URIs must be of the form 'runs:/<run_id>/run-relative/path/to/artifact'

# %%
loaded_model  = mlflow.pyfunc.load_model(model_info.model_uri)
predictions = loaded_model.predict(X_test)
iris_feature_name = datasets.load_iris().feature_names
result = pd.DataFrame(X_test,columns=iris_feature_name)
result["actual_class"] = y_test
result["predicted_class"] = predictions

# %%
result
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.5               2.5                4.0               1.3
# 1                 5.7               2.9                4.2               1.3
# 2                 5.4               3.4                1.5               0.4
# 3                 5.4               3.0                4.5               1.5
# 4                 4.6               3.4                1.4               0.3
# 5                 6.0               2.7                5.1               1.6
# 6                 5.1               3.7                1.5               0.4
# 7                 4.9               3.6                1.4               0.1
# 8                 5.6               2.5                3.9               1.1
# 9                 6.6               3.0                4.4               1.4
# 10                6.4               2.9                4.3               1.3
# 11                6.3               2.8                5.1               1.5
# 12                4.4               3.2                1.3               0.2
# 13                5.3               3.7                1.5               0.2
# 14                5.6               3.0                4.5               1.5
# 15                5.7               2.8                4.5               1.3
# 16                6.4               2.7                5.3               1.9
# 17                5.0               3.3                1.4               0.2
# 18                5.1               3.5                1.4               0.2
# 19                6.0               2.2                5.0               1.5
# 20                6.2               3.4                5.4               2.3
# 21                4.7               3.2                1.6               0.2
# 22                6.3               3.4                5.6               2.4
# 23                6.4               2.8                5.6               2.1
# 24                5.8               2.7                5.1               1.9
# 25                7.7               3.0                6.1               2.3
# 26                5.2               2.7                3.9               1.4
# 27                5.7               2.8                4.1               1.3
# 28                6.2               2.8                4.8               1.8
# 29                5.8               2.7                4.1               1.0
#
#     actual_class  predicted_class
# 0              1                1
# 1              1                1
# 2              0                0
# 3              1                1
# 4              0                0
# 5              1                2
# 6              0                0
# 7              0                0
# 8              1                1
# 9              1                1
# 10             1                1
# 11             2                2
# 12             0                0
# 13             0                0
# 14             1                1
# 15             1                1
# 16             2                2
# 17             0                0
# 18             0                0
# 19             2                1
# 20             2                2
# 21             0                0
# 22             2                2
# 23             2                2
# 24             2                2
# 25             2                2
# 26             1                1
# 27             1                1
# 28             2                2
# 29             1                1

# %% [markdown]
# ## Model Registry
