# %% [markdown]
# ## MLflow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")  #local host in this case

# %%
mlflow.set_experiment("Check loaclhost connection")
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Krish1",2)
# Out:
# 🏃 View run merciful-goat-259 at: http://127.0.0.1:5000/#/experiments/323637752626771435/runs/b98cae1b483e42c1b07ea281a72c9054
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/323637752626771435

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Krish2",2)
# Out:
# 🏃 View run rambunctious-sow-533 at: http://127.0.0.1:5000/#/experiments/323637752626771435/runs/8926327a2049429e87a7dbb4a426e5c8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/323637752626771435
